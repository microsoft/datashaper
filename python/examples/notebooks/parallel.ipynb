# %%
import asyncio

import numpy as np
import pandas as pd

# %%
from datashaper import Table, VerbCallbacks, new_row, parallel_verb


@parallel_verb(name="embed_verb_for_df")
async def embed_verb_for_df(
    chunk: Table, callbacks: VerbCallbacks, column: str, to: str, **_kwargs: dict
) -> Table:
    """Stub function to embed a verb for a dataframe."""
    chunk[to] = chunk[column].apply(lambda _x: np.random.rand(10))
    await asyncio.sleep(1)
    return chunk


@parallel_verb(name="embed_verb_for_row")
async def embed_verb_for_row(
    chunk: tuple, callbacks: VerbCallbacks, to: str, column: str, **_kwargs: dict
) -> tuple:
    """Stub function to embed a verb for a row in a table."""
    result = np.random.rand(10)
    await asyncio.sleep(1)
    return new_row(chunk, to, result)

# %%
gh_url = "https://raw.githubusercontent.com/darthtrevino/vast-mc3-data/main"
dtype = {"date(yyyyMMddHHmmss)": "string"}
vast1 = pd.read_csv(f"{gh_url}/csv-1700-1830.csv", dtype=dtype)
vast2 = pd.read_csv(f"{gh_url}/csv-1831-2000.csv", dtype=dtype)
vast3 = pd.read_csv(f"{gh_url}/csv-2001-2131.csv", dtype=dtype)

# %%
from datashaper.execution.execution_node import ExecutionNode
from datashaper.progress.types import Progress
from datashaper.workflow.workflow import Workflow
from datashaper.workflow.workflow_callbacks.noop_workflow_callback import (
    NoopWorkflowCallbacks,
)


class Callbacks(NoopWorkflowCallbacks):
    """A callback class to handle workflow events."""

    def on_step_progress(self, node: ExecutionNode, progress: Progress) -> None:
        """Handle when progress occurs."""
        print(f"Progress: {progress}")


workflow = Workflow(
    schema={
        "steps": [
            {
                "verb": "concat",
                "input": {"source": "vast1", "others": ["vast2", "vast3"]},
            },
            {
                "verb": "convert",
                "args": {
                    "column": "date(yyyyMMddHHmmss)",
                    "to": "datetime",
                    "type": "date",
                    "formatPattern": "yyyyMMddHHmmss",
                },
            },
            {
                "verb": "select",
                "args": {"columns": ["type", "datetime", "author", "message"]},
            },
            {
                "verb": "embed_verb_for_df",
                "args": {"to": "embedding", "column": "message", "chunk_size": 50},
            },
        ]
    },
    input_tables={"vast1": vast1, "vast2": vast2, "vast3": vast3},
)

await workflow.run(callbacks=Callbacks())
result = workflow.output()
result
# Out:
# Progress: Progress(percent=0, description=None, total_items=None, completed_items=None)
# Progress: Progress(percent=1, description=None, total_items=None, completed_items=None)
# Progress: Progress(percent=0, description=None, total_items=None, completed_items=None)
# Progress: Progress(percent=1, description=None, total_items=None, completed_items=None)
# Progress: Progress(percent=0, description=None, total_items=None, completed_items=None)
# Progress: Progress(percent=1, description=None, total_items=None, completed_items=None)
# Progress: Progress(percent=0, description=None, total_items=None, completed_items=None)
# /home/andresmor/.cache/pypoetry/virtualenvs/examples-gtU7jnqy-py3.10/lib/python3.10/site-packages/numpy/core/fromnumeric.py:59: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
# Progress: Progress(percent=None, description=None, total_items=82, completed_items=1)
# Progress: Progress(percent=None, description=None, total_items=82, completed_items=2)
# Progress: Progress(percent=None, description=None, total_items=82, completed_items=3)
# Progress: Progress(percent=None, description=None, total_items=82, completed_items=4)
# Progress: Progress(percent=None, description=None, total_items=82, completed_items=5)
# Progress: Progress(percent=None, description=None, total_items=82, completed_items=6)
# Progress: Progress(percent=None, description=None, total_items=82, completed_items=7)
# Progress: Progress(percent=None, description=None, total_items=82, completed_items=8)
# Progress: Progress(percent=None, description=None, total_items=82, completed_items=9)
# Progress: Progress(percent=None, description=None, total_items=82, completed_items=10)
# Progress: Progress(percent=None, description=None, total_items=82, completed_items=11)
# Progress: Progress(percent=None, description=None, total_items=82, completed_items=12)
# Progress: Progress(percent=None, description=None, total_items=82, completed_items=13)
# Progress: Progress(percent=None, description=None, total_items=82, completed_items=14)
# Progress: Progress(percent=None, description=None, total_items=82, completed_items=15)
# Progress: Progress(percent=None, description=None, total_items=82, completed_items=16)
# Progress: Progress(percent=None, description=None, total_items=82, completed_items=17)
# Progress: Progress(percent=None, description=None, total_items=82, completed_items=18)
# Progress: Progress(percent=None, description=None, total_items=82, completed_items=19)
# Progress: Progress(percent=None, description=None, total_items=82, completed_items=20)
# Progress: Progress(percent=None, description=None, total_items=82, completed_items=21)
# Progress: Progress(percent=None, description=None, total_items=82, completed_items=22)
# Progress: Progress(percent=None, description=None, total_items=82, completed_items=23)
# Progress: Progress(percent=None, description=None, total_items=82, completed_items=24)
# Progress: Progress(percent=None, description=None, total_items=82, completed_items=25)
# Progress: Progress(percent=None, description=None, total_items=82, completed_items=26)
# Progress: Progress(percent=None, description=None, total_items=82, completed_items=27)
# Progress: Progress(percent=None, description=None, total_items=82, completed_items=28)
# Progress: Progress(percent=None, description=None, total_items=82, completed_items=29)
# Progress: Progress(percent=None, description=None, total_items=82, completed_items=30)
# Progress: Progress(percent=None, description=None, total_items=82, completed_items=31)
# Progress: Progress(percent=None, description=None, total_items=82, completed_items=32)
# Progress: Progress(percent=None, description=None, total_items=82, completed_items=33)
# Progress: Progress(percent=None, description=None, total_items=82, completed_items=34)
# Progress: Progress(percent=None, description=None, total_items=82, completed_items=35)
# Progress: Progress(percent=None, description=None, total_items=82, completed_items=36)
# Progress: Progress(percent=None, description=None, total_items=82, completed_items=37)
# Progress: Progress(percent=None, description=None, total_items=82, completed_items=38)
# Progress: Progress(percent=None, description=None, total_items=82, completed_items=39)
# Progress: Progress(percent=None, description=None, total_items=82, completed_items=40)
# Progress: Progress(percent=None, description=None, total_items=82, completed_items=41)
# Progress: Progress(percent=None, description=None, total_items=82, completed_items=42)
# Progress: Progress(percent=None, description=None, total_items=82, completed_items=43)
# Progress: Progress(percent=None, description=None, total_items=82, completed_items=44)
# Progress: Progress(percent=None, description=None, total_items=82, completed_items=45)
# Progress: Progress(percent=None, description=None, total_items=82, completed_items=46)
# Progress: Progress(percent=None, description=None, total_items=82, completed_items=47)
# Progress: Progress(percent=None, description=None, total_items=82, completed_items=48)
# Progress: Progress(percent=None, description=None, total_items=82, completed_items=49)
# Progress: Progress(percent=None, description=None, total_items=82, completed_items=50)
# Progress: Progress(percent=None, description=None, total_items=82, completed_items=51)
# Progress: Progress(percent=None, description=None, total_items=82, completed_items=52)
# Progress: Progress(percent=None, description=None, total_items=82, completed_items=53)
# Progress: Progress(percent=None, description=None, total_items=82, completed_items=54)
# Progress: Progress(percent=None, description=None, total_items=82, completed_items=55)
# Progress: Progress(percent=None, description=None, total_items=82, completed_items=56)
# Progress: Progress(percent=None, description=None, total_items=82, completed_items=57)
# Progress: Progress(percent=None, description=None, total_items=82, completed_items=58)
# Progress: Progress(percent=None, description=None, total_items=82, completed_items=59)
# Progress: Progress(percent=None, description=None, total_items=82, completed_items=60)
# Progress: Progress(percent=None, description=None, total_items=82, completed_items=61)
# Progress: Progress(percent=None, description=None, total_items=82, completed_items=62)
# Progress: Progress(percent=None, description=None, total_items=82, completed_items=63)
# Progress: Progress(percent=None, description=None, total_items=82, completed_items=64)
# Progress: Progress(percent=None, description=None, total_items=82, completed_items=65)
# Progress: Progress(percent=None, description=None, total_items=82, completed_items=66)
# Progress: Progress(percent=None, description=None, total_items=82, completed_items=67)
# Progress: Progress(percent=None, description=None, total_items=82, completed_items=68)
# Progress: Progress(percent=None, description=None, total_items=82, completed_items=69)
# Progress: Progress(percent=None, description=None, total_items=82, completed_items=70)
# Progress: Progress(percent=None, description=None, total_items=82, completed_items=71)
# Progress: Progress(percent=None, description=None, total_items=82, completed_items=72)
# Progress: Progress(percent=None, description=None, total_items=82, completed_items=73)
# Progress: Progress(percent=None, description=None, total_items=82, completed_items=74)
# Progress: Progress(percent=None, description=None, total_items=82, completed_items=75)
# Progress: Progress(percent=None, description=None, total_items=82, completed_items=76)
# Progress: Progress(percent=None, description=None, total_items=82, completed_items=77)
# Progress: Progress(percent=None, description=None, total_items=82, completed_items=78)
# Progress: Progress(percent=None, description=None, total_items=82, completed_items=79)
# Progress: Progress(percent=None, description=None, total_items=82, completed_items=80)
# Progress: Progress(percent=None, description=None, total_items=82, completed_items=81)
# Progress: Progress(percent=None, description=None, total_items=82, completed_items=82)
# Progress: Progress(percent=None, description=None, total_items=82, completed_items=82)
# Progress: Progress(percent=1, description=None, total_items=None, completed_items=None)
#         type            datetime         author  \
# 0     mbdata 2014-01-23 17:00:00            POK
# 1     mbdata 2014-01-23 17:00:00  maha_Homeland
# 2     mbdata 2014-01-23 17:00:00       Viktor-E
# 3     mbdata 2014-01-23 17:00:00     KronosStar
# 4     mbdata 2014-01-23 17:00:00      AbilaPost
# ...      ...                 ...            ...
# 4058  mbdata 2014-01-23 21:33:10   plasticParts
# 4059  mbdata 2014-01-23 21:33:45   klingon4real
# 4060  mbdata 2014-01-23 21:34:00         lindyT
# 4061  mbdata 2014-01-23 21:34:00     dolls4sale
# 4062  mbdata 2014-01-23 21:34:45   worldWatcher
#
#                                                 message  \
# 0                                 Follow us @POK-Kronos
# 1     Don't miss a moment!  Follow our live coverage...
# 2     Come join us in the Park! Music tonight at Abi...
# 3     POK rally to start in Abila City Park. POK lea...
# 4     POK rally set to take place in Abila City Park...
# ...                                                 ...
# 4058  RT @AbilaPost unknown explosion heard from the...
# 4059  RT @CentralBulletin explosion heard at dancing...
# 4060  RT @KronosStar There has been an explosion fro...
# 4061                  RT @redisrad What was that? #boom
# 4062  RT @CentralBulletin explosion heard at dancing...
#
#                                               embedding
# 0     [0.992762302137496, 0.8471110011638578, 0.0234...
# 1     [0.9985802890794845, 0.7518555961995833, 0.817...
# 2     [0.46299571660610683, 0.32689315751677084, 0.3...
# 3     [0.5774714595393775, 0.6340547088991296, 0.765...
# 4     [0.35657516070159045, 0.10572059178242377, 0.3...
# ...                                                 ...
# 4058  [0.8149193811879802, 0.8466132815064984, 0.547...
# 4059  [0.25698503222622127, 0.5230854547999364, 0.06...
# 4060  [0.11418371721025533, 0.8810552054131907, 0.72...
# 4061  [0.3123928648418389, 0.8356350850641252, 0.576...
# 4062  [0.970464694197246, 0.03929747618553281, 0.552...
#
# [4063 rows x 5 columns]

# %%
from datashaper.execution.execution_node import ExecutionNode
from datashaper.progress.types import Progress
from datashaper.workflow.workflow import Workflow
from datashaper.workflow.workflow_callbacks.noop_workflow_callback import (
    NoopWorkflowCallbacks,
)


class Callbacks(NoopWorkflowCallbacks):
    """A callback class to handle workflow events."""

    def on_step_progress(self, node: ExecutionNode, progress: Progress) -> None:
        """Handle when progress occurs."""
        print(f"Progress: {progress}")


workflow = Workflow(
    schema={
        "steps": [
            {
                "verb": "concat",
                "input": {"source": "vast1", "others": ["vast2", "vast3"]},
            },
            {
                "verb": "convert",
                "args": {
                    "column": "date(yyyyMMddHHmmss)",
                    "to": "datetime",
                    "type": "date",
                    "formatPattern": "yyyyMMddHHmmss",
                },
            },
            {
                "verb": "select",
                "args": {"columns": ["type", "datetime", "author", "message"]},
            },
            {
                "verb": "embed_verb_for_row",
                "args": {
                    "to": "embedding",
                    "column": "message",
                    "max_parallelism": 256,
                },
            },
        ]
    },
    input_tables={"vast1": vast1, "vast2": vast2, "vast3": vast3},
)

await workflow.run(callbacks=Callbacks())
result = workflow.output()
result
# Out:
# Progress: Progress(percent=0, description=None, total_items=None, completed_items=None)
# Progress: Progress(percent=1, description=None, total_items=None, completed_items=None)
# Progress: Progress(percent=0, description=None, total_items=None, completed_items=None)
# Progress: Progress(percent=1, description=None, total_items=None, completed_items=None)
# Progress: Progress(percent=0, description=None, total_items=None, completed_items=None)
# Progress: Progress(percent=1, description=None, total_items=None, completed_items=None)
# Progress: Progress(percent=0, description=None, total_items=None, completed_items=None)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=1)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=2)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=3)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=4)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=5)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=6)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=7)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=8)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=9)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=10)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=11)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=12)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=13)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=14)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=15)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=16)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=17)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=18)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=19)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=20)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=21)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=22)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=23)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=24)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=25)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=26)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=27)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=28)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=29)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=30)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=31)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=32)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=33)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=34)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=35)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=36)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=37)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=38)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=39)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=40)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=41)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=42)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=43)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=44)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=45)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=46)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=47)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=48)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=49)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=50)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=51)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=52)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=53)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=54)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=55)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=56)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=57)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=58)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=59)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=60)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=61)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=62)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=63)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=64)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=65)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=66)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=67)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=68)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=69)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=70)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=71)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=72)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=73)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=74)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=75)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=76)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=77)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=78)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=79)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=80)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=81)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=82)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=83)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=84)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=85)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=86)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=87)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=88)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=89)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=90)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=91)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=92)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=93)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=94)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=95)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=96)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=97)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=98)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=99)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=100)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=101)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=102)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=103)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=104)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=105)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=106)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=107)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=108)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=109)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=110)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=111)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=112)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=113)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=114)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=115)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=116)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=117)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=118)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=119)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=120)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=121)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=122)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=123)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=124)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=125)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=126)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=127)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=128)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=129)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=130)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=131)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=132)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=133)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=134)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=135)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=136)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=137)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=138)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=139)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=140)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=141)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=142)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=143)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=144)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=145)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=146)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=147)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=148)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=149)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=150)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=151)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=152)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=153)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=154)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=155)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=156)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=157)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=158)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=159)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=160)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=161)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=162)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=163)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=164)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=165)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=166)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=167)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=168)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=169)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=170)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=171)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=172)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=173)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=174)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=175)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=176)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=177)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=178)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=179)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=180)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=181)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=182)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=183)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=184)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=185)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=186)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=187)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=188)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=189)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=190)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=191)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=192)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=193)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=194)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=195)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=196)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=197)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=198)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=199)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=200)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=201)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=202)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=203)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=204)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=205)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=206)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=207)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=208)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=209)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=210)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=211)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=212)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=213)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=214)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=215)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=216)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=217)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=218)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=219)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=220)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=221)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=222)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=223)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=224)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=225)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=226)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=227)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=228)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=229)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=230)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=231)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=232)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=233)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=234)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=235)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=236)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=237)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=238)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=239)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=240)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=241)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=242)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=243)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=244)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=245)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=246)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=247)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=248)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=249)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=250)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=251)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=252)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=253)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=254)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=255)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=256)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=257)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=258)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=259)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=260)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=261)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=262)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=263)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=264)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=265)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=266)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=267)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=268)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=269)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=270)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=271)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=272)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=273)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=274)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=275)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=276)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=277)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=278)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=279)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=280)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=281)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=282)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=283)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=284)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=285)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=286)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=287)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=288)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=289)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=290)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=291)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=292)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=293)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=294)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=295)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=296)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=297)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=298)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=299)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=300)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=301)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=302)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=303)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=304)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=305)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=306)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=307)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=308)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=309)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=310)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=311)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=312)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=313)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=314)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=315)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=316)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=317)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=318)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=319)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=320)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=321)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=322)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=323)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=324)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=325)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=326)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=327)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=328)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=329)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=330)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=331)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=332)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=333)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=334)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=335)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=336)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=337)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=338)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=339)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=340)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=341)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=342)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=343)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=344)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=345)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=346)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=347)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=348)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=349)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=350)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=351)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=352)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=353)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=354)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=355)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=356)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=357)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=358)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=359)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=360)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=361)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=362)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=363)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=364)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=365)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=366)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=367)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=368)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=369)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=370)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=371)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=372)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=373)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=374)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=375)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=376)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=377)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=378)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=379)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=380)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=381)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=382)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=383)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=384)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=385)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=386)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=387)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=388)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=389)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=390)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=391)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=392)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=393)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=394)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=395)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=396)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=397)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=398)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=399)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=400)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=401)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=402)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=403)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=404)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=405)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=406)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=407)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=408)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=409)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=410)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=411)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=412)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=413)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=414)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=415)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=416)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=417)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=418)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=419)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=420)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=421)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=422)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=423)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=424)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=425)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=426)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=427)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=428)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=429)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=430)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=431)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=432)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=433)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=434)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=435)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=436)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=437)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=438)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=439)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=440)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=441)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=442)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=443)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=444)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=445)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=446)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=447)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=448)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=449)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=450)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=451)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=452)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=453)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=454)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=455)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=456)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=457)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=458)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=459)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=460)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=461)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=462)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=463)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=464)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=465)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=466)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=467)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=468)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=469)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=470)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=471)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=472)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=473)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=474)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=475)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=476)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=477)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=478)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=479)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=480)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=481)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=482)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=483)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=484)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=485)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=486)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=487)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=488)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=489)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=490)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=491)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=492)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=493)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=494)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=495)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=496)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=497)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=498)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=499)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=500)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=501)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=502)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=503)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=504)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=505)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=506)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=507)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=508)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=509)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=510)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=511)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=512)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=513)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=514)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=515)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=516)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=517)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=518)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=519)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=520)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=521)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=522)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=523)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=524)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=525)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=526)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=527)
# ...
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=3914)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=3915)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=3916)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=3917)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=3918)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=3919)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=3920)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=3921)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=3922)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=3923)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=3924)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=3925)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=3926)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=3927)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=3928)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=3929)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=3930)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=3931)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=3932)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=3933)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=3934)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=3935)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=3936)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=3937)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=3938)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=3939)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=3940)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=3941)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=3942)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=3943)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=3944)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=3945)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=3946)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=3947)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=3948)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=3949)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=3950)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=3951)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=3952)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=3953)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=3954)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=3955)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=3956)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=3957)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=3958)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=3959)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=3960)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=3961)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=3962)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=3963)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=3964)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=3965)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=3966)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=3967)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=3968)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=3969)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=3970)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=3971)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=3972)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=3973)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=3974)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=3975)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=3976)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=3977)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=3978)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=3979)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=3980)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=3981)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=3982)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=3983)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=3984)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=3985)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=3986)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=3987)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=3988)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=3989)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=3990)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=3991)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=3992)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=3993)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=3994)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=3995)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=3996)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=3997)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=3998)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=3999)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=4000)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=4001)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=4002)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=4003)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=4004)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=4005)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=4006)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=4007)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=4008)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=4009)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=4010)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=4011)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=4012)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=4013)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=4014)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=4015)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=4016)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=4017)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=4018)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=4019)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=4020)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=4021)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=4022)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=4023)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=4024)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=4025)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=4026)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=4027)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=4028)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=4029)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=4030)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=4031)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=4032)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=4033)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=4034)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=4035)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=4036)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=4037)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=4038)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=4039)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=4040)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=4041)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=4042)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=4043)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=4044)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=4045)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=4046)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=4047)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=4048)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=4049)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=4050)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=4051)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=4052)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=4053)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=4054)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=4055)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=4056)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=4057)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=4058)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=4059)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=4060)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=4061)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=4062)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=4063)
# Progress: Progress(percent=None, description=None, total_items=4063, completed_items=4063)
# Progress: Progress(percent=1, description=None, total_items=None, completed_items=None)
#       Index    type            datetime         author  \
# 0         0  mbdata 2014-01-23 17:00:00            POK
# 1         1  mbdata 2014-01-23 17:00:00  maha_Homeland
# 2         2  mbdata 2014-01-23 17:00:00       Viktor-E
# 3         3  mbdata 2014-01-23 17:00:00     KronosStar
# 4         4  mbdata 2014-01-23 17:00:00      AbilaPost
# ...     ...     ...                 ...            ...
# 4058   4058  mbdata 2014-01-23 21:33:10   plasticParts
# 4059   4059  mbdata 2014-01-23 21:33:45   klingon4real
# 4060   4060  mbdata 2014-01-23 21:34:00         lindyT
# 4061   4061  mbdata 2014-01-23 21:34:00     dolls4sale
# 4062   4062  mbdata 2014-01-23 21:34:45   worldWatcher
#
#                                                 message  \
# 0                                 Follow us @POK-Kronos
# 1     Don't miss a moment!  Follow our live coverage...
# 2     Come join us in the Park! Music tonight at Abi...
# 3     POK rally to start in Abila City Park. POK lea...
# 4     POK rally set to take place in Abila City Park...
# ...                                                 ...
# 4058  RT @AbilaPost unknown explosion heard from the...
# 4059  RT @CentralBulletin explosion heard at dancing...
# 4060  RT @KronosStar There has been an explosion fro...
# 4061                  RT @redisrad What was that? #boom
# 4062  RT @CentralBulletin explosion heard at dancing...
#
#                                               embedding
# 0     [0.7261302990077598, 0.3656781673448264, 0.628...
# 1     [0.4540679483368807, 0.7026164705691877, 0.214...
# 2     [0.9526399323973125, 0.056928101809164855, 0.0...
# 3     [0.1366551234486959, 0.8261510701606365, 0.644...
# 4     [0.7359758903009926, 0.11936404559212188, 0.38...
# ...                                                 ...
# 4058  [0.8091847262774975, 0.8694422182168504, 0.425...
# 4059  [0.4276384589752016, 0.6595713997793372, 0.484...
# 4060  [0.33691410898314345, 0.8505349866410271, 0.01...
# 4061  [0.5203900721912476, 0.35986282416034265, 0.45...
# 4062  [0.47315277227975405, 0.45525259874480084, 0.4...
#
# [4063 rows x 6 columns]
